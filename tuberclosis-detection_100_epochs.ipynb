jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.480.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1020.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2123.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2078.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1875.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.585.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.926.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.335.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2368.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1600.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2437.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1178.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2004.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.884.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2269.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.837.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.611.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1421.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.935.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.564.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.271.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1835.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2249.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1580.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2365.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2305.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1997.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2023.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2315.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.827.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1078.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.469.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.159.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1064.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1593.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1640.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.168.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.5.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1246.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.357.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2271.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1525.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.768.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.148.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1861.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2158.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.982.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1118.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.574.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1806.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.281.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1389.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1927.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.269.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2049.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1518.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.453.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1491.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.294.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1075.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1138.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2351.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.64.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.805.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.864.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.161.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1388.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1552.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.990.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1095.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1066.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1306.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.85.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.262.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1731.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1705.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2082.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1291.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2036.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1915.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2211.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1906.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.227.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1024.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2419.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1447.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.378.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1812.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1635.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.493.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2336.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2458.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2104.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2142.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2008.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.891.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.245.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2095.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.852.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.270.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.876.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.571.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.435.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.344.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.885.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.2068.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1633.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1418.jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/TB Chest X-rays/TB.1054.jpg
# ...
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (375).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (254).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (439).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (14).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (207).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (192).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (44).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (467).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (406).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (130).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (498).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (471).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (317).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (402).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (100).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (409).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (140).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (20).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (302).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (440).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (58).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (119).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (433).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (477).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (337).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (260).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (94).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (361).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (81).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (357).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (377).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (306).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (37).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (382).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (287).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (5).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (340).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (7).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (383).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (455).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (380).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (54).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (303).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (365).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (4).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (295).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (349).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (165).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (449).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (159).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (272).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (410).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (93).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (322).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (242).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (150).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (344).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (425).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (179).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (345).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (129).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (114).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (450).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (286).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (229).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (458).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (270).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (210).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (405).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (371).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (57).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (310).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (214).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (23).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (135).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (6).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (145).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (351).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (112).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (301).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (96).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (121).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (55).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (76).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (209).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (182).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (413).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (269).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (384).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (173).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (420).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (321).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (235).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (392).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (62).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (82).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (421).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (24).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (36).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (187).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (514).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (250).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (126).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (487).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (185).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (33).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (282).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (101).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (495).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (26).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (502).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (266).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (456).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (71).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (441).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (319).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (59).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (257).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (318).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (400).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (184).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (30).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (312).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (80).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (460).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (431).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (147).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (240).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (219).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (271).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (280).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (228).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (283).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (186).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (39).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (152).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (333).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (512).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (342).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (122).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (88).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (354).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (328).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (348).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (343).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (299).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (238).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (15).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (338).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (504).jpg
# /kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images/Normal Chest X-rays/others (350).jpg

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# Set the number of classes based on your dataset structure
num_classes = 2
image_size = (224, 224)
batch_size = 32

# Create ImageDataGenerator for training and validation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values between 0 and 1
    shear_range=0.2,  # Apply random shear transformation
    zoom_range=0.2,   # Apply random zoom
    horizontal_flip=True,  # Randomly flip the image
    validation_split=0.2   # Split 20% data for validation
)

# Create ImageDataGenerator for training and validation
test_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values between 0 and 1
    shear_range=0.2,  # Apply random shear transformation
    zoom_range=0.2,   # Apply random zoom
    horizontal_flip=True,  # Randomly flip the image
    validation_split=0.2   # Split 20% data for validation
)

# Create ImageDataGenerator for training and validation
validation_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values between 0 and 1
    shear_range=0.2,  # Apply random shear transformation
    zoom_range=0.2,   # Apply random zoom
    horizontal_flip=True,  # Randomly flip the image
    validation_split=0.2   # Split 20% data for validation
)
# Set directories for the dataset
dataset_dir = '/kaggle/input/tb-dataset/Dataset of Tuberculosis Chest X-rays Images'

# Training data generator
train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',  # Use categorical mode for multi-class classification
    subset='training'  # Specify this is for training data
)

# Validation data generator
validation_generator = validation_datagen.flow_from_directory(
    dataset_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',  # Use categorical mode for multi-class classification
    subset='validation'  # Specify this is for validation data
)

# Test data generator

test_generator = test_datagen.flow_from_directory(
    dataset_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical', # Use categorical mode for multi-class classification
    subset='validation'
)
# Out:
# Found 2408 images belonging to 2 classes.
# Found 600 images belonging to 2 classes.
# Found 600 images belonging to 2 classes.

# %%
# Custom Hybrid CNN-RNN Model for 5-class classification
def create_hybrid_model(input_shape=(224, 224, 3), num_classes=2):
    model = models.Sequential()

    # CNN Layers for feature extraction
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))  # Output: (112, 112, 32)

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))  # Output: (56, 56, 64)

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))  # Output: (24, 24, 128)

    # Flatten the feature maps into a sequence
    model.add(layers.Reshape((24 * 24, 128)))  # Reshape to (576, 128)

    # BiLSTM for sequential processing
    model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
    model.add(layers.Bidirectional(layers.LSTM(32)))

    # Fully connected layer
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))

    # Output layer for multi-class classification (5 classes)
    model.add(layers.Dense(num_classes, activation='sigmoid'))  # 5-class classification

    return model

# %%
# Create the Hybrid CNN-RNN Model for 5-class classification
hybrid_model = create_hybrid_model()

# Compile the model
hybrid_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                     loss='binary_crossentropy',  # Use categorical crossentropy for multi-class classification
                     metrics=['accuracy'])

# Model summary for debugging
hybrid_model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 220, 220, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 110, 110, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 108, 108, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 106, 106, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 53, 53, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 51, 51, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 49, 49, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 576, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 576, 128)       │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 431,330 (1.65 MB)
#  Trainable params: 431,330 (1.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model using the train and validation generators
history = hybrid_model.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 62s 634ms/step - accuracy: 0.7799 - loss: 0.5985 - val_accuracy: 0.8300 - val_loss: 0.4596
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 441ms/step - accuracy: 0.8259 - loss: 0.4740 - val_accuracy: 0.8300 - val_loss: 0.4513
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 437ms/step - accuracy: 0.8307 - loss: 0.4625 - val_accuracy: 0.8300 - val_loss: 0.4468
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 439ms/step - accuracy: 0.8347 - loss: 0.4327 - val_accuracy: 0.8300 - val_loss: 0.4333
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 436ms/step - accuracy: 0.8385 - loss: 0.3670 - val_accuracy: 0.8117 - val_loss: 0.4347
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 430ms/step - accuracy: 0.8242 - loss: 0.3647 - val_accuracy: 0.8300 - val_loss: 0.3791
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 39s 482ms/step - accuracy: 0.8484 - loss: 0.3457 - val_accuracy: 0.8650 - val_loss: 0.3466
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.8637 - loss: 0.3126 - val_accuracy: 0.8600 - val_loss: 0.3174
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 435ms/step - accuracy: 0.8927 - loss: 0.2604 - val_accuracy: 0.8617 - val_loss: 0.2942
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s
100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 436ms/step - accuracy: 0.9917 - loss: 0.0266 - val_accuracy: 0.9917 - val_loss: 0.0287
# Epoch 87/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.9858 - loss: 0.0357 - val_accuracy: 0.9883 - val_loss: 0.0326
# Epoch 88/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 443ms/step - accuracy: 0.9906 - loss: 0.0243 - val_accuracy: 0.9883 - val_loss: 0.0364
# Epoch 89/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 435ms/step - accuracy: 0.9897 - loss: 0.0329 - val_accuracy: 0.9800 - val_loss: 0.0492
# Epoch 90/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 435ms/step - accuracy: 0.9945 - loss: 0.0234 - val_accuracy: 0.8900 - val_loss: 0.2956
# Epoch 91/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.9069 - loss: 0.2212 - val_accuracy: 0.9517 - val_loss: 0.1488
# Epoch 92/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 432ms/step - accuracy: 0.9817 - loss: 0.0631 - val_accuracy: 0.9833 - val_loss: 0.0556
# Epoch 93/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 435ms/step - accuracy: 0.9777 - loss: 0.0622 - val_accuracy: 0.9783 - val_loss: 0.0696
# Epoch 94/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 431ms/step - accuracy: 0.9882 - loss: 0.0395 - val_accuracy: 0.9867 - val_loss: 0.0455
# Epoch 95/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.9864 - loss: 0.0436 - val_accuracy: 0.9817 - val_loss: 0.0462
# Epoch 96/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 435ms/step - accuracy: 0.9918 - loss: 0.0286 - val_accuracy: 0.9917 - val_loss: 0.0278
# Epoch 97/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 425ms/step - accuracy: 0.9875 - loss: 0.0420 - val_accuracy: 0.9750 - val_loss: 0.0611
# Epoch 98/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 427ms/step - accuracy: 0.9922 - loss: 0.0221 - val_accuracy: 0.9883 - val_loss: 0.0311
# Epoch 99/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 427ms/step - accuracy: 0.9870 - loss: 0.0377 - val_accuracy: 0.9817 - val_loss: 0.0494
# Epoch 100/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 429ms/step - accuracy: 0.9915 - loss: 0.0354 - val_accuracy: 0.9800 - val_loss: 0.0481

# %%
# Evaluate the model on the validation data
test_loss, test_acc = hybrid_model.evaluate(test_generator)
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 353ms/step - accuracy: 0.9846 - loss: 0.0454
# Testing Accuracy: 98.50%

# %%
import matplotlib.pyplot as plt 
# plot the accuracy
plt.title("Accuracy of CNN-LSTM Model")
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# Plot accuracy and loss
plt.title("Loss of Hybrid CNN-LSTM Model ")
# plot the loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Get the true labels and predictions
Y_pred = hybrid_model.predict(validation_generator)
y_pred_classes = np.argmax(Y_pred, axis=1)  # Predicted class indices
y_true = validation_generator.classes  # True class labels

# Classification report for precision, recall, f1-score
print("Classification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=validation_generator.class_indices.keys()))
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step
# Classification Report:
#
#                      precision    recall  f1-score   support
#
# Normal Chest X-rays       0.21      0.21      0.21       102
#     TB Chest X-rays       0.84      0.84      0.84       498
#
#            accuracy                           0.73       600
#           macro avg       0.52      0.52      0.52       600
#        weighted avg       0.73      0.73      0.73       600

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=validation_generator.class_indices.keys(), yticklabels=validation_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.ylabel('True Labels')
plt.xlabel('Predicted Labels')
plt.show()
